# %%
from hw2skeleton.cluster import cluster_by_partitioning, cluster_hierarchically
from hw2skeleton.io import read_active_sites, write_clustering, write_mult_clusterings
active_sites = read_active_sites('data')
# Out:
# Read in 136 active sites

# %%
cluster_by_partitioning(active_sites,2)
# Out:
# [['10701', '10814', '17622', '1806', '18773', '19267', '20856', '22711', '24634', '26246', '27031', '27312', '28672', '29773', '34088', '34958', '35014', '37224', '37237', '38031', '38846', '39117', '39299', '39939', '42202', '42296', '43878', '45127', '46975', '47023', '53272', '54203', '56029', '64258', '69893', '70919', '71389', '73462', '81563', '81859', '82886', '83227', '83741', '85492', '88042', '91796', '93192', '93456', '94652', '94719', '96099', '98170'], ['13052', '14181', '15813', '17526', '20326', '23319', '23760', '23812', '24307', '25196', '25551', '25878', '26095', '276', '28919', '29047', '29209', '32054', '32088', '33838', '34047', '34563', '3458', '36257', '3733', '37438', '38181', '38472', '40084', '41719', '41729', '42074', '42269', '42633', '46042', '4629', '46495', '49624', '50018', '50362', '52235', '52954', '55996', '56394', '57370', '57481', '57602', '57644', '58445', '6040', '61242', '62186', '63064', '63634', '63703', '64392', '65815', '68578', '70005', '72058', '73183', '73624', '7674', '7780', '78796', '81697', '81816', '8208', '82212', '82238', '82993', '8304', '83394', '84035', '85232', '91194', '91426', '91911', '93168', '94372', '97218', '97612', '9776', '98797']]
# [['10701',
#   '10814',
#   '17622',
#   '1806',
#   '18773',
#   '19267',
#   '20856',
#   '22711',
#   '24634',
#   '26246',
#   '27031',
#   '27312',
#   '28672',
#   '29773',
#   '34088',
#   '34958',
#   '35014',
#   '37224',
#   '37237',
#   '38031',
#   '38846',
#   '39117',
#   '39299',
#   '39939',
#   '42202',
#   '42296',
#   '43878',
#   '45127',
#   '46975',
#   '47023',
#   '53272',
#   '54203',
#   '56029',
#   '64258',
#   '69893',
#   '70919',
#   '71389',
#   '73462',
#   '81563',
#   '81859',
#   '82886',
#   '83227',
#   '83741',
#   '85492',
#   '88042',
#   '91796',
#   '93192',
#   '93456',
#   '94652',
#   '94719',
#   '96099',
#   '98170'],
#  ['13052',
#   '14181',
#   '15813',
#   '17526',
#   '20326',
#   '23319',
#   '23760',
#   '23812',
#   '24307',
#   '25196',
#   '25551',
#   '25878',
#   '26095',
#   '276',
#   '28919',
#   '29047',
#   '29209',
#   '32054',
#   '32088',
#   '33838',
#   '34047',
#   '34563',
#   '3458',
#   '36257',
#   '3733',
#   '37438',
#   '38181',
#   '38472',
#   '40084',
#   '41719',
#   '41729',
#   '42074',
#   '42269',
#   '42633',
#   '46042',
#   '4629',
#   '46495',
#   '49624',
#   '50018',
#   '50362',
#   '52235',
#   '52954',
#   '55996',
#   '56394',
#   '57370',
#   '57481',
#   '57602',
#   '57644',
#   '58445',
#   '6040',
#   '61242',
#   '62186',
#   '63064',
#   '63634',
#   '63703',
#   '64392',
#   '65815',
#   '68578',
#   '70005',
#   '72058',
#   '73183',
#   '73624',
#   '7674',
#   '7780',
#   '78796',
#   '81697',
#   '81816',
#   '8208',
#   '82212',
#   '82238',
#   '82993',
#   '8304',
#   '83394',
#   '84035',
#   '85232',
#   '91194',
#   '91426',
#   '91911',
#   '93168',
#   '94372',
#   '97218',
#   '97612',
#   '9776',
#   '98797']]
